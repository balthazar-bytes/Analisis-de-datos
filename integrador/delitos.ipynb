# %% [markdown]
# # ejercicio integrado primera parte

# %% [markdown]
# ## delitos en CABA

# %% [markdown]
# __este trabajo trata de analizar todas las cosas vistas en el curso__

# %% [markdown]
# ![Buenos Aires](data:image/jpeg;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
