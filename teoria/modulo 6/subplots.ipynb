# %% [markdown]
# ## subplots
# a veces queremos representar varios graficos dentro de la misma figura
#
#
# la funcion subplot toma la cantidad de filas y columnas en las que deben acomodarse los subgraficos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
plt.hist(np.random.randn(500))
plt.title("historigrama")
plt.subplot(1,2,2)
plt.pie([6,9,15,24,35])
plt.title("grafico de torta")
# Out:
# Text(0.5, 1.0, 'grafico de torta')

# %% [markdown]
# ## interfaz orientada a objetos
# La interfaz orientada a objetos permite ponerle
# nombre a los objetos como figuras y subplots,
# de modo que podamos referirnos a ellos en
# cualquier parte y en cualquier orden. Y ahora
# ya no vamos a trabajar con funciones sino con
# métodos sobre esos objetos.

# %%
fig, ax = plt.subplots()
ax.plot([2,4,8,6,5], label="Datos")
ax.set_title("Grafico")
ax.set_xlabel("Eje x")
ax.set_ylabel("Eje y")
ax.legend()

# %%
fig, axs = plt.subplots(2,2)
axs[0,0].plot([3,6,2,5])
axs[0,1].hist(np.random.rand(100))
axs[1,0].pie([23,46,22,24,54,30])
# Out:
# ([<matplotlib.patches.Wedge at 0x7bca881d2450>,
# ...
#  [Text(1.028280833130357, 0.3906898107408728, ''),
#   Text(0.1299377980701312, 1.0922985711941062, ''),
#   Text(-0.8980134835810161, 0.6352729990379634, ''),
#   Text(-1.0932901583469903, -0.12131211671392525, ''),
#   Text(-0.24960765550690955, -1.0713057538874438, ''),
#   Text(0.9789218801333719, -0.5017090318064291, '')])
